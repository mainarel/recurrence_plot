# %% [markdown]
# <a href="https://colab.research.google.com/github/mainarel/recurrence_plot/blob/main/recurrence_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyts
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.5 MB 5.1 MB/s
# ...

# %%
import matplotlib.pyplot as plt
from pyts.image import RecurrencePlot
import numpy as np

# %% [markdown]
# # Тестовый пример

# %%
times = np.arange(0,100,1)
datas = np.random.rand(100)

# %%
time_points = np.linspace(0, 4 * np.pi, 1000)
x = np.sin(time_points)
#x = np.random.rand(500)
X = np.array([x])

# Recurrence plot transformation
rp = RecurrencePlot(threshold = 0.1)
X_rp = rp.fit_transform(X)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(X_rp[0], cmap='rainbow', origin='lower')
plt.title('Recurrence Plot')
plt.colorbar()
plt.show()

# %% [markdown]
# # Задача 1.

# %%
num = np.loadtxt('/content/Haptics_TEST.txt', dtype=np.float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff('/content/Haptics_TEST.arff')
df = pd.DataFrame(data[0])
df
# Out:
#          att1      att2      att3      att4      att5      att6      att7  \
# 0   -1.288572  0.006059 -2.151010 -1.322679 -0.863004 -1.618088 -1.307570
# 1   -1.441763  0.065805 -1.560006 -2.241373 -1.350893 -1.008068 -1.563718
# 2   -1.395546  0.131045 -0.255258 -1.429271 -2.205048 -2.095837 -1.465255
# 3   -0.900786  0.930432  0.192374 -1.312239 -1.954817 -1.446459 -0.667134
# 4   -1.282733  0.153161 -0.106876 -1.176818 -2.036198 -2.147285 -1.663571
# ..        ...       ...       ...       ...       ...       ...       ...
# 303 -1.090063  0.247846 -0.205158 -1.225077 -1.681043 -1.335844 -0.768273
# 304 -1.363994  0.233969 -1.249162 -2.260655 -1.607888 -0.935933 -1.269033
# 305 -1.161621  0.420159  0.079964 -1.137156 -2.060329 -2.114048 -1.532795
# 306 -1.073752  0.179118  0.469507  0.026853 -0.763280 -1.509540 -1.937156
# 307 -0.796944  0.642463  0.452588 -0.595266 -1.552968 -1.840083 -1.475969
#
#          att8      att9     att10  ...   att1084   att1085   att1086  \
# ...

# %%
samples = np.array([(num[2])[1:], (num[11])[1:], (num[0])[1:], (num[1])[1:], (num[99])[1:]])

# %%
plt.figure(figsize=(10, 5))
plt.grid()
plt.title("original dataset")
plt.ylabel("x-shift")
plt.plot((num[2])[1:], label = '1')
plt.plot((num[11])[1:], label = '2')
plt.plot((num[0])[1:], label = '3')
plt.plot((num[1])[1:], label = '4')
plt.plot((num[99])[1:], label = '5')
plt.legend()

# %%
X = samples
rp = RecurrencePlot()
X_rp = rp.fit_transform(X)

for i in range (5):
     dd = plt.figure(i)
     ax = dd.add_subplot()
     print('Recurrence Plot для ', i+1, '-го человека')
     plt.imshow(X_rp[i], cmap='magma', origin='lower')
     plt.colorbar()
     plt.show()
# Out:
# Recurrence Plot для  1 -го человека
# Recurrence Plot для  2 -го человека
# Recurrence Plot для  3 -го человека
# Recurrence Plot для  4 -го человека
# Recurrence Plot для  5 -го человека

# %% [markdown]
# # Задача 2.

# %%
xmove = np.loadtxt('/content/ToeSegmentation1_TEST.txt', dtype=np.float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
data1 = arff.loadarff('/content/ToeSegmentation1_TEST.arff')
df1 = pd.DataFrame(data1[0])
df1

# %%
samples1 = np.array([(xmove[0])[1:], (xmove[223])[1:]])

# %%
plt.figure(figsize=(10, 5))
plt.grid()
plt.title("original dataset")
plt.ylabel("x-shift")
plt.plot((xmove[0])[1:], label = 'type 0')
plt.plot((xmove[223])[1:], label = 'type 1')

plt.legend()

# %%
X1 = samples1
rp1 = RecurrencePlot()
X_rp1 = rp1.fit_transform(X1)

for i in range (2):
     dd = plt.figure(i)
     ax = dd.add_subplot()
     print('Recurrence Plot для ', i+1, '-го типа')
     plt.imshow(X_rp1[i], cmap='magma', origin='lower')
     plt.colorbar()
     plt.show()
# Out:
# Recurrence Plot для  1 -го типа
# Recurrence Plot для  2 -го типа

# %% [markdown]
# # Задание 3.

# %%
indicators = np.loadtxt('/content/LargeKitchenAppliances_TEST.txt', dtype=np.float)

# %%
data2 = arff.loadarff('/content/LargeKitchenAppliances_TEST.arff')
df2 = pd.DataFrame(data2[0])
df2

# %%
samples2 = np.array([(indicators[0])[1:], (indicators[195])[1:], (indicators[370])[1:]])

# %%
plt.figure(figsize=(10, 5))
plt.grid()
plt.title("original dataset")
plt.ylabel("indication")
plt.plot((indicators[0])[1:], label = 'class 1')
plt.plot((indicators[195])[1:], label = 'class 2')
plt.plot((indicators[370])[1:], label = 'class 3')

plt.legend()

# %%
X2 = samples2
rp2 = RecurrencePlot(threshold = 0.00001)
X_rp2 = rp2.fit_transform(X2)

for i in range (3):
     dd = plt.figure(i)
     ax = dd.add_subplot()
     print('Recurrence Plot для ', i+1, '-го класса')
     plt.imshow(X_rp2[i], cmap='magma', origin='lower')
     plt.colorbar()
     plt.show()
# Out:
# Recurrence Plot для  1 -го класса
# Recurrence Plot для  2 -го класса
# Recurrence Plot для  3 -го класса

# %% [markdown]
# # Дополнительная задача:

# %%
x = np.random.rand(300)
X = np.array([x])
rp = RecurrencePlot()
X_rp = rp.fit_transform(X)



plt.figure(figsize=(10, 10))
plt.imshow(X_rp[0], cmap='rainbow', origin='lower')
plt.title('Recurrence Plot равномерного распределения')
plt.colorbar()
plt.show()

# %%
plt.plot(x)

# %%
import random

nums = [] 
mu = 100
sigma = 50
    
for i in range(300): 
    temp = random.normalvariate(mu, sigma)
    nums.append(temp) 
        
# plotting a graph 
plt.plot(nums) 
plt.show()

# %%
X = np.array([nums])
rp = RecurrencePlot()
X_rp = rp.fit_transform(X)



plt.figure(figsize=(10, 10))
plt.imshow(X_rp[0], cmap='rainbow', origin='lower')
plt.title('Recurrence Plot нормального распределения')
plt.colorbar()
plt.show()
